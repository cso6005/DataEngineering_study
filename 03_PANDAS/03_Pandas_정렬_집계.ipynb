# %% [markdown]
# ## 정렬
# ### index명/컬럼명을 순 정렬
#
# ### 거의 index명 기준 정렬
# - #### sort_index(axis, ascending=True)
#     - axis
#         - **index명 기준 정렬(행) : 'index' 또는 0 (기본값)**
#         - columnm 명 기준 정렬(열) : 'columns' 또는 1
#             - 컬럼명이 정렬. 사실 이럴 일 없다.
#     - ascending
#         - 정렬방식
#         - True(기본): 오름차순, False: 내림차순
#     - inplace
#         - 원본에 적용 여부
#         - False(기본): 변경한 복사본 반환
#         - True : 원본을 변경

# %%
import pandas as pd

df = pd.read_csv('data/movie.csv')
df.shape
# Out:
# (4916, 28)

# %%
# 컬럼명이 정렬.
df.sort_index(axis = 1)
# df.sort_index(axis = 'columns')
# Out:
#       actor_1_facebook_likes     actor_1_name  actor_2_facebook_likes  \
# 0                     1000.0      CCH Pounder                   936.0
# 1                    40000.0      Johnny Depp                  5000.0
# 2                    11000.0  Christoph Waltz                   393.0
# 3                    27000.0        Tom Hardy                 23000.0
# 4                      131.0      Doug Walker                    12.0
# ...                      ...              ...                     ...
# 4911                   637.0      Eric Mabius                   470.0
# 4912                   841.0      Natalie Zea                   593.0
# 4913                     0.0      Eva Boehnke                     0.0
# 4914                   946.0        Alan Ruck                   719.0
# 4915                    86.0      John August                    23.0
#
#           actor_2_name  actor_3_facebook_likes          actor_3_name  \
# ...

# %%
# movie_title 을 인덱스로 설정
df.set_index('movie_title', inplace = True)
df
# Out:
#                                             color      director_name  \
# movie_title
# Avatar                                      Color      James Cameron
# Pirates of the Caribbean: At World's End    Color     Gore Verbinski
# Spectre                                     Color         Sam Mendes
# The Dark Knight Rises                       Color  Christopher Nolan
# Star Wars: Episode VII - The Force Awakens    NaN        Doug Walker
# ...                                           ...                ...
# Signed Sealed Delivered                     Color        Scott Smith
# The Following                               Color                NaN
# A Plague So Pleasant                        Color   Benjamin Roberds
# Shanghai Calling                            Color        Daniel Hsia
# My Date with Drew                           Color           Jon Gunn
#
#                                             num_critic_for_reviews  duration  \
# movie_title
# ...

# %%
# axis 기본값 = 0 ascending 기본값 = 오름차순
df.sort_index()
# Out:
#                             color        director_name  \
# movie_title
# #Horror                     Color         Tara Subkoff
# 10 Cloverfield Lane         Color     Dan Trachtenberg
# 10 Days in a Madhouse       Color        Timothy Hines
# 10 Things I Hate About You  Color           Gil Junger
# 10,000 B.C.                   NaN  Christopher Barnard
# ...                           ...                  ...
# [Rec] 2                     Color      Jaume Balagueró
# eXistenZ                    Color     David Cronenberg
# xXx                         Color            Rob Cohen
# xXx: State of the Union     Color         Lee Tamahori
# Æon Flux                    Color         Karyn Kusama
#
#                             num_critic_for_reviews  duration  \
# movie_title
# #Horror                                       35.0     101.0
# 10 Cloverfield Lane                          411.0     104.0
# 10 Days in a Madhouse                          1.0     111.0
# ...

# %%
# 행 슬라이싱.
# 정렬 후 원하는 행만 보려고 슬라이싱.

df.sort_index()['Avator':'Spectre']
df.sort_index().loc['Avator':'Spectre', 'color':'duration']
# Out:
#                               color    director_name  num_critic_for_reviews  \
# movie_title
# Avengers: Age of Ultron       Color      Joss Whedon                   635.0
# Awake                         Color      Joby Harold                   133.0
# Away We Go                    Color       Sam Mendes                   217.0
# Ayurveda: Art of Being        Color        Pan Nalin                    15.0
# B-Girl                        Color       Emily Dell                     8.0
# ...                             ...              ...                     ...
# Spartacus: War of the Damned  Color              NaN                    68.0
# Spawn                         Color  Mark A.Z. Dippé                    70.0
# Special                       Color     Hal Haberman                    56.0
# Species                       Color  Roger Donaldson                    97.0
# Spectre                       Color       Sam Mendes                   602.0
#
# ...

# %%
# A~B 까지 조회. -> 정렬 후 슬라이싱 


df2 = df.sort_index() # 정렬된 데이터프레임
df2 

# A로 시작하는 영화 ~ C로 시작하는 영화 앞까지 범위로 조회
df2['A':'C']



df.sort_index().loc['A':'C','color':'duration'].head(20)
# Out:
#                                                           color  \
# movie_title
# A Beautiful Mind                                          Color
# A Beginner's Guide to Snuff                               Color
# A Better Life                                             Color
# A Bridge Too Far                                Black and White
# A Bug's Life                                              Color
# A Charlie Brown Christmas                                 Color
# A Christmas Carol                                         Color
# A Christmas Story                                         Color
# A Cinderella Story                                        Color
# A Civil Action                                            Color
# A Dangerous Method                                        Color
# A Dog of Flanders                                         Color
# A Dog's Breakfast                                         Color
# ...

# %%
# 내림차순 조회
df.sort_index(ascending = False)
# Out:
#                             color        director_name  \
# movie_title
# Æon Flux                    Color         Karyn Kusama
# xXx: State of the Union     Color         Lee Tamahori
# xXx                         Color            Rob Cohen
# eXistenZ                    Color     David Cronenberg
# [Rec] 2                     Color      Jaume Balagueró
# ...                           ...                  ...
# 10,000 B.C.                   NaN  Christopher Barnard
# 10 Things I Hate About You  Color           Gil Junger
# 10 Days in a Madhouse       Color        Timothy Hines
# 10 Cloverfield Lane         Color     Dan Trachtenberg
# #Horror                     Color         Tara Subkoff
#
#                             num_critic_for_reviews  duration  \
# movie_title
# Æon Flux                                     178.0      93.0
# xXx: State of the Union                       77.0     101.0
# xXx                                          191.0     132.0
# ...

# %% [markdown]
# ## 2.컬럼 값 기준 정렬
# - #### sort_values(by, ascending, inplace)
#     - by
#         - 정렬기준 컬럼명
#         - **해당 컬럼을 기준으로 행을 정렬한다.**
#         - 여러 컬럼에 대해 정렬할 경우 리스트에 담아 전달
#     - ascending
#         - 정렬방식
#         - True(기본): 오름차순, False: 내림차순
#         - 여러컬럼에 대해 정렬할 경우 정렬방식도 리스트에 담아 전달
#     - inplace
#         - 원본에 적용 여부
#         - False(기본): 변경한 복사본 반환
#         - True : 원본을 변경
#     - 결측치는 방식과 상관없이 마지막에 나온다.

# %%
# director_name을 기준으로 행 정렬 (오름차순)
df.sort_values("director_name")   # order by director_name


# director_name을 기준으로 행 정렬 (내림차순)
df.sort_values("director_name", ascending=False) # order by director_name desc


df.sort_values("director_name", ascending = False)
# Out:
#                     color       director_name  num_critic_for_reviews  \
# movie_title
# Bizarre             Color       Étienne Faure                     9.0
# Sur le seuil        Color        Éric Tessier                     9.0
# Mambo Italiano      Color    Émile Gaudreault                    67.0
# The Oxford Murders  Color  Álex de la Iglesia                    71.0
# Along the Roadside  Color       Zoran Lisinac                    17.0
# ...                   ...                 ...                     ...
# Heroes              Color                 NaN                    75.0
# Home Movies         Color                 NaN                    11.0
# Revolution          Color                 NaN                    23.0
# Happy Valley        Color                 NaN                    11.0
# The Following       Color                 NaN                    43.0
#
#                     duration  director_facebook_likes  actor_3_facebook_likes  \
# movie_title
# ...

# %%
# 2차 정렬 => list로

# order by duration, imdb_score : duration 정렬 후 imdb_score 정렬
# duration 이 같은 값들 중 또 다른 기준컬럼으로 정렬하겠다.

df.sort_values(['duration', 'imdb_score']) # 둘 다 오름차순
# Out:
#                                                color     director_name  \
# movie_title
# The Touch                                      Color        Jane Clark
# Shaun the Sheep                                Color               NaN
# Robot Chicken                                  Color               NaN
# Vessel                                         Color       Clark Baker
# Wal-Mart: The High Cost of Low Price           Color  Robert Greenwald
# ...                                              ...               ...
# Wolf Creek                                     Color               NaN
# Black Water Transit                            Color         Tony Kaye
# Harry Potter and the Deathly Hallows: Part II  Color        Matt Birch
# Destiny                                        Color   Joseph Kosinski
# War & Peace                                    Color               NaN
#
#                                                num_critic_for_reviews  \
# movie_title
# ...

# %%
# n 차 정렬에서 정렬방식이 다를 때 ascending 에서 순서대로 리스트에 넣어주면 됨.
# order by duration asc, imdb_score desc

df.sort_values(['duration', 'imdb_score'], ascending = [True, False]) # 오름. 내림
# Out:
#                                       color      director_name  \
# movie_title
# Shaun the Sheep                       Color                NaN
# The Touch                             Color         Jane Clark
# Robot Chicken                         Color                NaN
# Vessel                                Color        Clark Baker
# Wal-Mart: The High Cost of Low Price  Color   Robert Greenwald
# ...                                     ...                ...
# Dil Jo Bhi Kahey...                   Color      Romesh Sharma
# Romantic Schemer                      Color          Valentine
# The Naked Ape                         Color     Daniel Mellitz
# N-Secure                              Color  David M. Matthews
# Hum To Mohabbat Karega                Color        Kundan Shah
#
#                                       num_critic_for_reviews  duration  \
# movie_title
# Shaun the Sheep                                         12.0       7.0
# ...

# %% [markdown]
# #### 메소드 체인 : 행 조건, 정렬 등 여러 작업이 이어져서 하나의 구문으로 가능하다.
#     - 그렇게 되는 이유 작업 결과가 데이터프레임이니깐
#     - 나온 결과에 또 처리하고 그 결과에 대해 또 처리하고 이어서 가능.

# %%
# 메소드 체인
df[df['duration']>250].sort_values('director_name').head(10)

df[df['duration']>250].sort_values('director_name')[['director_name', 'duration']]
# Out:
#                                     director_name  duration
# movie_title
# The Legend of Suriyothai      Chatrichalerm Yukol     300.0
# Apocalypse Now               Francis Ford Coppola     289.0
# Cleopatra                    Joseph L. Mankiewicz     251.0
# Heaven's Gate                      Michael Cimino     325.0
# Arn: The Knight Templar              Peter Flinth     270.0
# Gods and Generals                     Ron Maxwell     280.0
# Gettysburg                            Ron Maxwell     271.0
# Once Upon a Time in America          Sergio Leone     251.0
# Blood In, Blood Out               Taylor Hackford     330.0
# Das Boot                        Wolfgang Petersen     293.0
# Trapped                                       NaN     511.0
# Carlos                                        NaN     334.0
# The Company                                   NaN     286.0

# %% [markdown]
# ## 2 집계함수

# %% [markdown]
# ## flights.csv (항공기 운항 기록 데이터)
# - MONTH : 비행 월
# - DAY : 비행 일
# - WEEKDAY : 비행 요일 - 1(월요일)~7(일요일)
# - AIRLINE : 항공사 코드
#      - UA:	United Air Lines Inc.
#      - AA:	American Airlines Inc.
#      - US:	US Airways Inc.
#      - F9:	Frontier Airlines Inc.
#      - B6:	JetBlue Airways
#      - OO:	Skywest Airlines Inc.
#      - AS:	Alaska Airlines Inc.
#      - NK:	Spirit Air Lines
#      - WN:	Southwest Airlines Co.
#      - DL:	Delta Air Lines Inc.
#      - EV:	Atlantic Southeast Airlines
#      - HA:	Hawaiian Airlines Inc.
#      - MQ:	American Eagle Airlines Inc.
#      - VX:	Virgin America
# - ORG_AIR : 출발공항
# - DEST_AIR : 도착공항
# - SCHED_DEP : 출발예정시각
# - DEP_DELAY : 출발지연시간(분)
# - AIR_TIME : 비행시간(분)
# - DIST : 비행거리(마일)
# - SCHED_ARR : 도착예정시각
# - ARR_DELAY : 도착지연시간(분)
# - DIVERTED : 회항여부(1: True, 0: False)
# - CANCELLED : 취소여부(1: True, 0: False)

# %%
import pandas as pd

flights = pd.read_csv('data/flights.csv')
flights.shape
# Out:
# (58492, 14)

# %%
flights.columns
flights.head()

# 가장 우선이 데이터를 전체적으로 보는 것이다. 데이터가 어떤 형식인지 어떤 값인지 파악해야 한다. 그리고 내가 원하는 처리를 하기 위해서 다른 처리가 필요없는지(전처리) 등등..
# Out:
#    MONTH  DAY  WEEKDAY AIRLINE ORG_AIR DEST_AIR  SCHED_DEP  DEP_DELAY  \
# 0      1    1        4      WN     LAX      SLC       1625       58.0
# 1      1    1        4      UA     DEN      IAD        823        7.0
# 2      1    1        4      MQ     DFW      VPS       1305       36.0
# 3      1    1        4      AA     DFW      DCA       1555        7.0
# 4      1    1        4      WN     LAX      MCI       1720       48.0
#
#    AIR_TIME  DIST  SCHED_ARR  ARR_DELAY  DIVERTED  CANCELLED
# 0      94.0   590       1905       65.0         0          0
# 1     154.0  1452       1333      -13.0         0          0
# 2      85.0   641       1453       35.0         0          0
# 3     126.0  1192       1935       -7.0         0          0
# 4     166.0  1363       2225       39.0         0          0

# %%
flights.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58492 entries, 0 to 58491
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   MONTH      58492 non-null  int64
#  1   DAY        58492 non-null  int64
#  2   WEEKDAY    58492 non-null  int64
#  3   AIRLINE    58492 non-null  object
#  4   ORG_AIR    58492 non-null  object
#  5   DEST_AIR   58492 non-null  object
#  6   SCHED_DEP  58492 non-null  int64
#  7   DEP_DELAY  57659 non-null  float64
#  8   AIR_TIME   57474 non-null  float64
#  9   DIST       58492 non-null  int64
#  10  SCHED_ARR  58492 non-null  int64
#  11  ARR_DELAY  57474 non-null  float64
#  12  DIVERTED   58492 non-null  int64
#  13  CANCELLED  58492 non-null  int64
# dtypes: float64(3), int64(8), object(3)
# memory usage: 6.2+ MB

# %%
flights.isnull().sum()
# Out:
# MONTH           0
# DAY             0
# WEEKDAY         0
# AIRLINE         0
# ORG_AIR         0
# DEST_AIR        0
# SCHED_DEP       0
# DEP_DELAY     833
# AIR_TIME     1018
# DIST            0
# SCHED_ARR       0
# ARR_DELAY    1018
# DIVERTED        0
# CANCELLED       0
# dtype: int64

# %% [markdown]
# ### 범주형을 찾을 수 있어야 한다. => group by
# - Object type    &   int type (ex. 월, 일, ...)

# %%
# object 타입의 컬럼 데이터가 범주형인지 단순 문자열인지 알아야 한다.
flights['AIRLINE'].nunique() # 14개 고유값이면 범주형인 지 알 수 있다.
# Out:
# 14

# %%
# object 타입의 범주 확인
flights['AIRLINE'].value_counts() # .sort_index
# Out:
# DL    10601
# AA     8900
# WN     8418
# UA     7792
# OO     6588
# EV     5858
# MQ     3471
# US     1615
# NK     1516
# F9     1317
# VX      993
# AS      768
# B6      543
# HA      112
# Name: AIRLINE, dtype: int64

# %%
# object 타입의 범주 확인
flights['ORG_AIR'].value_counts()
flights['DEST_AIR'].value_counts()
# Out:
# LAX    1991
# SFO    1637
# ORD    1634
# DEN    1581
# DFW    1454
#        ...
# MMH       4
# ITO       2
# CEC       2
# IMT       2
# FAI       1
# Name: DEST_AIR, Length: 271, dtype: int64

# %%
# int의 경우 범주형 타입일 수 도 있다. 확인 해봐야함.

flights['MONTH'].value_counts().sort_index()
# Out:
# 1     5003
# 2     4608
# 3     5485
# 4     5326
# 5     5545
# 6     5672
# 7     5754
# 8     5635
# 9     5235
# 11    5098
# 12    5131
# Name: MONTH, dtype: int64

# %%
# 기술통계량 확인
flights.describe()
# Out:
#               MONTH           DAY       WEEKDAY     SCHED_DEP     DEP_DELAY  \
# count  58492.000000  58492.000000  58492.000000  58492.000000  57659.000000
# mean       6.220646     15.702096      3.926862   1387.984836     10.921192
# std        3.358484      8.760846      1.995777    482.810792     36.146210
# min        1.000000      1.000000      1.000000      5.000000    -24.000000
# 25%        3.000000      8.000000      2.000000   1000.000000     -4.000000
# 50%        6.000000     16.000000      4.000000   1353.000000     -1.000000
# 75%        9.000000     23.000000      6.000000   1805.000000     10.000000
# max       12.000000     31.000000      7.000000   2359.000000   1194.000000
#
#            AIR_TIME          DIST     SCHED_ARR     ARR_DELAY      DIVERTED  \
# count  57474.000000  58492.000000  58492.000000  57474.000000  58492.000000
# mean     115.928576    872.900072   1549.399832      5.812315      0.002342
# ...

# %%
flights['MONTH'].value_counts()

# MOMTH는 범주형 컬럼이다. 이 Series 에서 value_counts() 하면 각 범주형 데이터 별로 갯수를 세어주는 함수이다.
# Out:
# 7     5754
# 6     5672
# 8     5635
# 5     5545
# 3     5485
# 4     5326
# 9     5235
# 12    5131
# 11    5098
# 1     5003
# 2     4608
# Name: MONTH, dtype: int64

# %% [markdown]
# ## 기술통계메소드들을 이용한 데이터 집계
# ### 주요 기술통계 메소드
#
# |함수|설명|
# |-|-|
# |**sum()**|합계|
# |**mean()**|평균|
# |**median()**|중위수|
# |**mode()**|최빈값|
# |**quantile()**|분위수|
# |**std()**|표준편차|
# |**var()**|분산|
# |**count()**|결측치를 제외한 원소 개수(행의 갯수를 센다)|
# |**min()**|최소값|
# |**max()**|최대값|
# |**idxmax()**|최대값 index|
# |**idxmin()**|최소값 index|
# |**unique()**|고유값|
# |**nunique()**|고유값의 개수|
#
# <center>cf) value_counts()는 Series에만 사용할 수 있다.</center>
#
# - DataFrame에 위의 기술 통계 메소드들을 적용할 경우 컬럼별로 계산
#
#
# - sum(), mode(), max(), min(), unique(), nunique(), count()는 문자열에 적용가능
#     - (문자열에서 mode(), unique(), numique(), count()는 중요)
#     - sum() 되긴 하지만, 무쓸모.
#     - max(), min() 유니코드 기준
#     - idxmax(), idxmin() 는 문자열 컬럼에 사용할 수 없다.
#         - numpy 에서 np.argmax(), np.argmin()을 사용한다.
#
#
# - 기본적으로 결측치(NA)는 제외(없는 행으로)하고 처리한다.
#     - 결측치 제외하지 않으려면 **skipna=False**로 설정

# %%
# 한 컬럼에 대한 flights['MOMTH'] : Series 에 대한 통계량

# MOMTH 는 범주형. 사실 최대값 최소값 평균 합계 등 수치통계가 필요없다. 
# 데이터가 정수형태이지만, 정수의 계산을 위해 사용되는 데이터가 아니다.
flights['MONTH'].max(), flights['MONTH'].min(), flights['MONTH'].mean(), flights['MONTH'].sum()

# 범주형이니 최빈값 확인이 더 중요한 통계값이다. 
flights['MONTH'].mode()
# Out:
# 0    7
# dtype: int64

# %%
# flights : DataFrame 에 대한 통계량 -> 컬럼별 통계량을 반환(Series)

flights.max()
# Out:
# MONTH            12
# DAY              31
# WEEKDAY           7
# AIRLINE          WN
# ORG_AIR         SFO
# DEST_AIR        YUM
# SCHED_DEP      2359
# DEP_DELAY    1194.0
# AIR_TIME      577.0
# DIST           4502
# SCHED_ARR      2359
# ARR_DELAY    1185.0
# DIVERTED          1
# CANCELLED         1
# dtype: object

# %%
# 평균
flights.mean()

# 데이터 프레임 내 있는 문자열 데이터 때문에 이를 집계함수 처리하는 것에 대한 경고메시지가 뜬다.
# Out:
# C:\Users\CSYJ\anaconda3\envs\ml\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
# MONTH           6.220646
# DAY            15.702096
# WEEKDAY         3.926862
# SCHED_DEP    1387.984836
# DEP_DELAY      10.921192
# AIR_TIME      115.928576
# DIST          872.900072
# SCHED_ARR    1549.399832
# ARR_DELAY       5.812315
# DIVERTED        0.002342
# CANCELLED       0.015062
# dtype: float64

# %%
# number : 숫자형 (모든 실수, 정수타입)  
# include='number'  exclude='object'

# 통계처리 가능한 number 숫자형 데이터만을 조회해서 이들의 평균 구하기

flights.select_dtypes(include=['number']).mean()
# Out:
# MONTH           6.220646
# DAY            15.702096
# WEEKDAY         3.926862
# SCHED_DEP    1387.984836
# DEP_DELAY      10.921192
# AIR_TIME      115.928576
# DIST          872.900072
# SCHED_ARR    1549.399832
# ARR_DELAY       5.812315
# DIVERTED        0.002342
# CANCELLED       0.015062
# dtype: float64

# %%
# 결측치 포함해서 계산. 결측치를 포함하여 계산하니 평균 결과가 NaN 나오는 것을 확인할 수 있다.
flights.select_dtypes(exclude=['object']).mean(skipna=False)

# df.mean(skipna=False)
# Out:
# MONTH           6.220646
# DAY            15.702096
# WEEKDAY         3.926862
# SCHED_DEP    1387.984836
# DEP_DELAY            NaN
# AIR_TIME             NaN
# DIST          872.900072
# SCHED_ARR    1549.399832
# ARR_DELAY            NaN
# DIVERTED        0.002342
# CANCELLED       0.015062
# dtype: float64

# %% [markdown]
# ### aggregate(func, axis=0, \*args, \*\*kwargs)
# ### 또는 agg(func, axis=0, \*args, \**kwargs)
#
# - 두개가 똑같은데 이름만 다른 것. 줄임말. agg쓰면 된다.
#
#
# - **DataFrame, Series의 메소드로 집계결과를 다양한 형태로 묶어서 볼때 사용한다.**
# - **사용자 정의 집계메소드를 사용할 때도 편리하다.**
#
#
# - 매개변수
#     - func
#         - 집계 함수 지정
#             - 하나 : 함수명 / 여러개 : 함수리스트 / (문자열)
#                 - 판다스 제공 집계메소드들은 문자열로 ("max")
#                 - 사용자정의 집계함수는 함수 객체로 전달
#             - 딕션어리 : {'집계할컬럼' : 집계함수, ... }
#                 - key 컬럼, values 집계함수
#                 - 컬럼별로 다른 집계를 할 경우(a컬럼은 합, b컬럼은평균 ...)
#     - axis
#         - 데이터프레임이 이차원이니 집계도 두 방향으로 할 수 있다.
#         - **0** 또는 'index' (기본값): 컬럼 별 집계 (**수직 방향으로 계산**)
#             - (행, 열) : 컬럼별로 행 데이터로 집계하니 행 없어지고 각 컬럼에 대한 값으로 결과 나옴
#             - 각 컬럼에 대한 집계
#         - **1** 또는 'columns': 행 별 집계 (**수평 방향으로 계산**)
#             - 각 행에 대한 집계
#
#     - \*args, \**kwargs
#         - **함수에 전달할 매개변수.**
#         - 함수 하나일 때만 가능. 리스트에 여러 개 넣은 경우엔 사용할 수 없다.
#         - 집계함수는 첫번째 매개변수로 Series를 받는다. 그 이외의 매개변수가 있는 경우.

# %%
grade = pd.read_csv('save_data/grade1.csv', index_col='id')

grade
# Out:
#       korean  math
# id
# id-1   100.0    80
# id-2     NaN    50
# id-3    70.0    90
# id-4    90.0   100
# id-5    85.0   100

# %%
# defalut : axis = 0 (행, 열) -> 각 컬럼 별로 행 데이터를 계산해서 
# -> 열에 대한 값으로 나옴. series 인덱스에 컬럼명 들어가고 값에 각 컬럼의 계산결과가 나온다.
# 집계함수가 여러 개면 인덱스에 집계함수, 컬럼에 컬럼명들 나올 것.

grade.sum()
# Out:
# korean    345.0
# math      420.0
# dtype: float64

# %%
grade.sum(axis=1)
# Out:
# id
# id-1    180.0
# id-2     50.0
# id-3    160.0
# id-4    190.0
# id-5    185.0
# dtype: float64

# %% [markdown]
# #### 적용

# %%
# Series 에 적용

# 도착지연시간의 평균, 최대값, 최소값

# 여러개 통계량 : 메소드들을 [] 리스토로 묶어서 전달
# pandas 제공 메소드들 : 문자열 메소드 이름만 제공

flights['ARR_DELAY'].agg(["mean","max","min"])
# Out:
# mean       5.812315
# max     1185.000000
# min      -60.000000
# Name: ARR_DELAY, dtype: float64

# %%
# DataFrame에 적용
flights.agg(['min', 'max']).T
# Out:
#             min     max
# MONTH         1      12
# DAY           1      31
# WEEKDAY       1       7
# AIRLINE      AA      WN
# ORG_AIR     ATL     SFO
# DEST_AIR    ABE     YUM
# SCHED_DEP     5    2359
# DEP_DELAY -24.0  1194.0
# AIR_TIME    8.0   577.0
# DIST         67    4502
# SCHED_ARR     1    2359
# ARR_DELAY -60.0  1185.0
# DIVERTED      0       1
# CANCELLED     0       1

# %%
flights.select_dtypes(exclude=['object']).agg(['count','mean','std','min', 'max', 'median', 'quantile'])
# Out:
#                  MONTH           DAY       WEEKDAY     SCHED_DEP  \
# count     58492.000000  58492.000000  58492.000000  58492.000000
# mean          6.220646     15.702096      3.926862   1387.984836
# std           3.358484      8.760846      1.995777    482.810792
# min           1.000000      1.000000      1.000000      5.000000
# max          12.000000     31.000000      7.000000   2359.000000
# median        6.000000     16.000000      4.000000   1353.000000
# quantile      6.000000     16.000000      4.000000   1353.000000
#
#              DEP_DELAY      AIR_TIME          DIST     SCHED_ARR  \
# count     57659.000000  57474.000000  58492.000000  58492.000000
# mean         10.921192    115.928576    872.900072   1549.399832
# std          36.146210     71.679591    624.996805    518.599952
# min         -24.000000      8.000000     67.000000      1.000000
# max        1194.000000    577.000000   4502.000000   2359.000000
# ...

# %%
# quantile(q = ) 는 매개변수가 있다. 
# 사실 여러 집계를 한번에 조회하려고 agg 쓰는 건데 하나의 함수에 대해서만 가변인자가 전달할 수 있다.
# 그렇기에 이 가변인자는 사용자 정의의 통계함수를 agg를 이용해 사용할 때 적용한다.

# 판다스 제공 함수를 쓸 때 하나일 때는 굳이. 
# 함수에 전달하는 값은 통계함수가 하나일 때만 적용된다.

 
flights.agg("quantile", q=[0.25,0.5,0.75])
# Out:
#       MONTH   DAY  WEEKDAY  SCHED_DEP  DEP_DELAY  AIR_TIME    DIST  SCHED_ARR  \
# 0.25    3.0   8.0      2.0     1000.0       -4.0      61.0   391.0     1159.0
# 0.50    6.0  16.0      4.0     1353.0       -1.0      97.0   690.0     1603.0
# 0.75    9.0  23.0      6.0     1805.0       10.0     152.0  1199.0     1959.0
#
#       ARR_DELAY  DIVERTED  CANCELLED
# 0.25      -12.0       0.0        0.0
# 0.50       -4.0       0.0        0.0
# 0.75        9.0       0.0        0.0

# %%
# 컬럼별로 다른 통계량을 조회할 경우 -> 딕셔너리 {컬럼명 : 통계함수,...}
flights.agg({"ARR_DELAY":"mean", "DEP_DELAY":"sum"})
# Out:
# ARR_DELAY         5.812315
# DEP_DELAY    629705.000000
# dtype: float64

# %%
flights.agg({"ARR_DELAY":"mean", "DEP_DELAY":["sum","mean"]})
# Out:
#       ARR_DELAY      DEP_DELAY
# mean   5.812315      10.921192
# sum         NaN  629705.000000

# %% [markdown]
# # Groupby
# - 특정 열을 기준으로 데이터셋을 묶는다.
# - ~~ 별 집계를 할 때 사용한다.
# - 구문
#     - DF.groupby('그룹으로묶을기준컬럼')['집계할 컬럼'].집계함수()
#         - groupby에 여러개의 컬럼을 기준으로 나눌 경우 리스트에 묶어서 전달한다.
#         - 집계할 컬럼이 여러개인 경우 리스트로 묶어준다.
#     - 집계함수
#         - 기술통계 함수들
#         - agg()/aggregate()
#             - 여러 다른 집계함수 호출시(여러 집계를 같이 볼경우)
#             - 사용자정의 집계함수 호출시
#             - 컬럼별로 다른 집계함수들을 호출할 경우

# %%
# AIRIINE 별로 집계
G = flights.groupby('AIRLINE')


# 어떻게 그룹으로 묶였는지 확인 (평소에는 이 작업 쓸 일 없음)
G.groups #{'AA':[AA인 인덱스명] , ...}
# Out:
# {'AA': [3, 6, 8, 15, 26, 32, 33, 36, 37, 41, 46, 47, 48, 55, 62, 66, 73, 75, 76, 87, 89, 97, 98, 107, 120, 122, 128, 131, 133, 146, 160, 171, 174, 178, 179, 188, 200, 201, 206, 221, 267, 270, 279, 305, 309, 311, 321, 330, 332, 342, 343, 347, 348, 380, 381, 382, 390, 393, 398, 402, 404, 405, 419, 427, 430, 431, 441, 449, 451, 455, 457, 466, 476, 491, 493, 497, 509, 514, 521, 527, 528, 537, 550, 551, 556, 560, 568, 572, 587, 589, 592, 612, 613, 618, 624, 626, 628, 634, 640, 652, ...], 'AS': [38, 198, 241, 277, 397, 450, 453, 500, 518, 591, 718, 737, 741, 808, 820, 867, 872, 1005, 1106, 1146, 1292, 1437, 1530, 1559, 1609, 1636, 1747, 1786, 1810, 1826, 1892, 1921, 2010, 2151, 2269, 2446, 2526, 2576, 2586, 2941, 3112, 3125, 3171, 3176, 3413, 3483, 3494, 3596, 3678, 3734, 3891, 3910, 3937, 3989, 4099, 4128, 4326, 4397, 4432, 4587, 4743, 4799, 4841, 4850, 4912, 4987, 5099, 5154, 5176, 5254, 5261, 5297, 5356, 5372, 5496, 5667, 5685, 5688, 5877, 5976, 6016, 6079, 6122, 6245, 6255, 6393, 6529,
# ...

# %%
# 묶고 나서 뭘 집계해서 반환할까~?~?~?~?

# AIRLINE 별 (그룹바이하고) 도착딜레이시간의 평균(원하는 컬럼집계)

flights.groupby('AIRLINE')['ARR_DELAY'].mean()
# Out:
# AIRLINE
# AA     5.542661
# AS    -0.833333
# B6     8.692593
# DL     0.339691
# EV     7.034580
# F9    13.630651
# HA     4.972973
# MQ     6.860591
# NK    18.436070
# OO     7.593463
# UA     7.765755
# US     1.681105
# VX     5.348884
# WN     6.397353
# Name: ARR_DELAY, dtype: float64

# %%
# AIRLINE 별  출발, 도착 딜레이 시간의 평균
flights.groupby('AIRLINE')[['DEP_DELAY','ARR_DELAY']].mean()

flights.groupby('AIRLINE')[['DEP_DELAY', 'ARR_DELAY']].mean()
# Out:
#          DEP_DELAY  ARR_DELAY
# AIRLINE
# AA       11.274057   5.542661
# AS        1.808594  -0.833333
# B6       14.287823   8.692593
# DL        7.242450   0.339691
# EV        9.092625   7.034580
# F9       14.310398  13.630651
# HA        2.571429   4.972973
# MQ       11.094323   6.860591
# NK       19.514401  18.436070
# OO        9.662279   7.593463
# UA       16.210485   7.765755
# US        4.361355   1.681105
# VX        8.918946   5.348884
# WN       12.639366   6.397353

# %%
# AIRLINE 별 출발, 도착 딜레이 시간의 최소, 최대값
flights.groupby('AIRLINE')[['DEP_DELAY', 'ARR_DELAY']].agg(['min', 'max'])

# 인덱스 : group by # 이중 컬럼 : 각 컬럼에 대한 min과 max
# Out:
#         DEP_DELAY         ARR_DELAY
#               min     max       min     max
# AIRLINE
# AA          -15.0   835.0     -60.0   858.0
# AS          -22.0   338.0     -57.0   344.0
# B6          -19.0   348.0     -51.0   331.0
# DL          -17.0   755.0     -57.0   741.0
# EV          -17.0   672.0     -39.0   669.0
# F9          -19.0   852.0     -43.0   839.0
# HA          -24.0   298.0     -44.0   298.0
# MQ          -12.0   342.0     -37.0   357.0
# NK          -16.0   461.0     -39.0   474.0
# OO          -20.0   735.0     -44.0   724.0
# UA          -18.0  1194.0     -58.0  1185.0
# US          -15.0   439.0     -51.0   431.0
# VX          -13.0   253.0     -51.0   236.0
# WN          -14.0   476.0     -52.0   493.0

# %%
# AIRLINE 별 출발 딜레이- 최소,최대값, 도착 딜레이- 합계, 평균 
# (컬럼별로 다른 통계량 조회) -> agg 딕셔너리로

flights.groupby('AIRLINE').agg({"DEP_DELAY":["min","max"], "ARR_DELAY":["sum","mean"]})
# Out:
#         DEP_DELAY         ARR_DELAY
#               min     max       sum       mean
# AIRLINE
# AA          -15.0   835.0   48332.0   5.542661
# AS          -22.0   338.0    -640.0  -0.833333
# B6          -19.0   348.0    4694.0   8.692593
# DL          -17.0   755.0    3580.0   0.339691
# EV          -17.0   672.0   40076.0   7.034580
# F9          -19.0   852.0   17788.0  13.630651
# HA          -24.0   298.0     552.0   4.972973
# MQ          -12.0   342.0   22736.0   6.860591
# NK          -16.0   461.0   27396.0  18.436070
# OO          -20.0   735.0   48788.0   7.593463
# UA          -18.0  1194.0   59641.0   7.765755
# US          -15.0   439.0    2678.0   1.681105
# VX          -13.0   253.0    5274.0   5.348884
# WN          -14.0   476.0   53162.0   6.397353

# %% [markdown]
# ###  복수열 기준 그룹핑
# - 두개 이상의 열을 그룹으로 묶을 수 있다.
# - groupby의 매개변수에 그룹으로 묶을 컬럼들의 이름을 리스트로 전달한다.

# %%
# 항공사별의 월별 도착 딜레이 시간의 평균
# 다중 그룹
flights.groupby(['AIRLINE','MONTH'])['ARR_DELAY'].mean()

# 컬럼이 하나라 series로 반환. 
# multi index  : AIRLINE~ MONTH 부분 전체가 INDEX이다. 



|    INDEX      |   values  |
# Out:
# AIRLINE  MONTH
# AA       1         9.436282
#          2         6.262032
#          3        10.639535
#          4         1.503628
#          5         7.549231
#                     ...
# WN       7        13.458750
#          8         6.542675
#          9        -1.232824
#          11        1.846154
#          12        8.947575
# Name: ARR_DELAY, Length: 149, dtype: float64

# %%
result = flights.groupby(['AIRLINE','MONTH'])['ARR_DELAY'].mean()

# Seires 의 multi index 조회할 때는!
result['AA',1]

# %%
# 항공사 요일별 회항/ 취소 횟수

flights.groupby(['AIRLINE','WEEKDAY'])[['DIVERTED','CANCELLED']].sum()
# Out:
#                  DIVERTED  CANCELLED
# AIRLINE WEEKDAY
# AA      1               6         41
#         2               2          9
#         3               2         16
#         4               5         20
#         5               1         18
# ...                   ...        ...
# WN      3               2         18
#         4               4         10
#         5               0          7
#         6               3         10
#         7               3          7
#
# [98 rows x 2 columns]

# %%
# 값을 보면 0과 1로 이뤄져있다. yes 1  no 0.

flights[['DIVERTED','CANCELLED']].agg(['min','max'])
# Out:
#      DIVERTED  CANCELLED
# min         0          0
# max         1          1

# %%
# count 는 결측치가 아닌 행수! 를 세는 것. count하면 1도 0도 결측치 빼고 행을 다 샌다.
# 1인 것만 세야 한다 -> sum() 해주면 1인 행 갯수를 구할 수 있다

flights.groupby(['AIRLINE','WEEKDAY'])[['DIVERTED','CANCELLED']].agg(['sum','mean']).head(10)


flights.groupby(['AIRLINE','WEEKDAY'])[['DIVERTED','CANCELLED']].mean().head(10)
# Out:
#                  DIVERTED  CANCELLED
# AIRLINE WEEKDAY
# AA      1        0.004699   0.032106
#         2        0.001631   0.007341
#         3        0.001494   0.011949
#         4        0.003751   0.015004
#         5        0.000786   0.014151
#         6        0.008000   0.018667
#         7        0.000753   0.021837
# AS      1        0.000000   0.000000
#         2        0.000000   0.000000
#         3        0.000000   0.000000

# %% [markdown]
# ## SQL having 처럼 집계한 것 중 특정 조건의 항목만 보기
# - 집계 후 boolean indexing으로 having절 처리

# %%
# 항공사별 취소 건수가 100 건 이상인 결과만 보고싶다.

flights.groupby('AIRLINE')['CANCELLED'].sum()[flights.groupby('AIRLINE')['CANCELLED'].sum() >= 100]

# 복잡. 변수로 뽑아서 하라.

re = flights.groupby('AIRLINE')['CANCELLED'].sum()
re[re >= 100]
# Out:
# AIRLINE
# AA    154
# EV    146
# MQ    152
# OO    142
# Name: CANCELLED, dtype: int64

# %% [markdown]
# ## 사용자 정의 집계함수를 만들어 적용
#
# ### 사용자 정의 집계 함수 정의
#
#
# - 매개변수
#     1. Series 또는 DataFrame을 받을 매개변수(필수)
#     2. 필요한 값을 받을 매개변수를 선언한다. (선택)
#
# ### agg() 를 사용해 사용자 정의 집계 함수 호출
#
#
# - ***axis 항목 있음. 함수 정의 시 인자 axis = 0 지정해주기. 호출 할 때 매개변수 키워드 인자 적어주기***
#
#
# - DataFrame.agg(func=None, axis=0, \*args, \*\*kwargs)
#     - axis : 사용자 정의 함수에 전달할 값들(Series)의 축 지정
#
#
# - Series.agg(func=None, axis=0, \*args, \*\*kwargs)
#     - DataFrame의 agg와 매개변수 구조를 맞추기 위해 axis 지정한다. (kwargs를 이용해 매개변수 전달할 경우 axis는 생략해도 된다. - axis기본값 0을 그냥 쓰면 되므로. - keyword 인자 뒤에 position 인자는 안되서 *args로 값 전달시에는 axis를 지정해야 한다.)
#
#
# - ***그룹으로 나눠서
# - ***axis 항목 없음.
#
# - DataFrameGroupBy.agg(func, \*args, \*\*kwargs) :
#     - axis 지정안함.
#     - 사용자 함수에 Series를 group 별로 전달한다.
#
#
# - SeriesGroupBy.agg(func=None,  \*args, \*\*kwargs)
#     - axis 지정안함
#     - 사용자 함수에 Series를 group 별로 전달한다.
#
#
# - \*args, \*\*kwargs는 사용자 정의 함수에 선언한 매개변수가 있을 경우 전달할 값을 전달한다.
#     - 키워드 인자를 이용해 가변인자로 전달하는 것이 편하다.

# %%
flights.groupby('AIRLINE')['MONTH'] # 하나의 컬럼에 대한 조회면 Series. 


# axis 항목 있음. 함수 정의 시 인자 axis = 0 지정해주기. 호출 할 때 매개변수 키워드 인자 적어주기
# 지금 default 적용할 것이기 때문에 안 적어준 것이다.

# Skipna = 안 적고 False만 적으면 axis 값으로 인식한다.
# => 키워드인자 적어주기
flights['ARR_DELAY'].agg("sum", skipna=False)
# Out:
# nan

# %% [markdown]
# #### 매개변수 없는 사용자 정의 함수
# - 최대 값과 최소값의 차이를 반환

# %%
# 사용자정의 집계함수(통계함수) ==> 최대값과 최소값의 차이를 구하는 함수 만들기!

import numpy as np

# 매개변수로 Series나 DataFrame 을 받을 변수, 그 외에 필요한 변수를 추가 선언하면됨.
def max_min_diff(X):
    # X : Series, DataFrame을 받을 변수
    
    # X가 수치형(int, float)이 아니면 예외발생
    if X.dtypes == "object":   # np.object => object 타입
        raise TypeError("수치형 타입만 계산할 수 있습니다.")     # 예외처리
        
    return X.max() - X.min()

# %%
max_min_diff(flights['ARR_DELAY']) # 한 컬럼에 대한 Series를 넣음.
# Out:
# 1245.0

# %%
max_min_diff(flights['DEP_DELAY'])
# Out:
# 1218.0

# %% [markdown]
# #### 판다스 제공 함수 : 함수이름은 문자열로 제공.
# #### 사용자 정의 통계량 함수 : 함수 객체 를 넣어야 함.

# %%
# ARR_DELAY 의 최소값, 최대값, 최대값과 최소값의 차이
# 함수 자체를 넣어줘야 함


flights['ARR_DELAY'].agg(['min','max', max_min_diff])
# Out:
# min              -60.0
# max             1185.0
# max_min_diff    1245.0
# Name: ARR_DELAY, dtype: float64

# %%
# 위는 값넣어서내가 호출한 것

# 이거는 my_agg가 값 넣어서 호출함.

def my_agg(X. fun): # X  : func(self.data)
    return fun(X)

my_agg(flights['ARR_DELAY'], max_min_diff)

# %%
# 그룹바이 한 데이터프레임에 대한.
# 그룹별로 세 함수들이 호출된것. 그룹14개 14번 호출.

flights.groupby('AIRLINE')[['DEP_DELAY', 'ARR_DELAY']].agg(['min', 'max', max_min_diff])



flights.groupby(['AIRLINE','MONTH'])[['DEP_DELAY','ARR_DELAY']].agg(['min', 'max', max_min_diff])

flights.groupby(['AIRLINE','MONTH']).agg({'DEP_DELAY':max_min_diff, 'ARR_DELAY':['min','max', max_min_diff]})
# Out:
#                  DEP_DELAY ARR_DELAY
#               max_min_diff       min    max max_min_diff
# AIRLINE MONTH
# AA      1            765.0     -42.0  732.0        774.0
#         2            305.0     -41.0  311.0        352.0
#         3            256.0     -38.0  248.0        286.0
#         4            651.0     -52.0  626.0        678.0
#         5            352.0     -45.0  339.0        384.0
# ...                    ...       ...    ...          ...
# WN      7            304.0     -39.0  290.0        329.0
#         8            300.0     -32.0  284.0        316.0
#         9            319.0     -36.0  284.0        320.0
#         11           260.0     -41.0  244.0        285.0
#         12           485.0     -52.0  493.0        545.0
#
# [149 rows x 4 columns]

# %% [markdown]
# # TODO
# 1. data/diamonds.csv 를 읽어 DataFrame 생성
# 2. 1에서 생성한 DataFrame의 정보 조회
#     - 배열의 shape조회
#     - 컬럼들의 정보조회
#     - 상/하위 5개 행 조회
#         - csv 파일 읽기
#         - shape
#         - info()
#         - head()
#         - tail()
#         - isnull().sum() => 컬럼별 null 체크 (sum() 한번더 하면 총개수)
#         - describe() : 숫자형-기술통계값, 문자열-총개수, 유니크값, 최빈값
# 3. carat, price, depth의 합계, 평균, 최대, 최소 조회
# 4. price는 최대, 최소, color는 고유값의 개수를 조회
# 5. cut의 고유값별 개수를 조회
# 6. cut별 가격(price) 평균 조회
# 7. cut별 가격 평균중 4000이상만 조회
# 8. clarity별 carat 평균과 표준편차 조회
# 9. cut과 color 별로 가격은 평균을 carat은 최대값을 조회
# 10. 9번 문제의 결과에서 가격의 평균이 5000이상이고 carat의 최대값이 3이상인 결과만 조회

# %%
.read() 전에 해당 데이터를 확인하자.

컬럼이 설정되어 있는지, 어떤 내용이 컬럼명인지
인덱스는 설정되어있지 않는지
쉼표가 구분자인지
결측치 여부 (눈으로 확인이 어렵지만)

# %%
#1
import pandas as pd
dia = pd.read_csv('data/diamonds.csv')

# %%
#2
dia.shape
dia.columns
dia.head()
dia.tail()
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64

# %%
dia.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53940 non-null  float64
#  1   cut      53940 non-null  object
#  2   color    53940 non-null  object
#  3   clarity  53940 non-null  object
#  4   depth    53940 non-null  float64
#  5   table    53940 non-null  float64
#  6   price    53940 non-null  int64
#  7   x        53940 non-null  float64
#  8   y        53940 non-null  float64
#  9   z        53940 non-null  float64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 4.1+ MB

# %%
dia.isnull().sum()
# Out:
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# price      0
# x          0
# y          0
# z          0
# dtype: int64

# %%
dia.describe()
# Out:
#               carat         depth         table         price             x  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean       0.797940     61.749405     57.457184   3932.799722      5.731157
# std        0.474011      1.432621      2.234491   3989.439738      1.121761
# min        0.200000     43.000000     43.000000    326.000000      0.000000
# 25%        0.400000     61.000000     56.000000    950.000000      4.710000
# 50%        0.700000     61.800000     57.000000   2401.000000      5.700000
# 75%        1.040000     62.500000     59.000000   5324.250000      6.540000
# max        5.010000     79.000000     95.000000  18823.000000     10.740000
#
#                   y             z
# count  53940.000000  53940.000000
# mean       5.734526      3.538734
# std        1.142135      0.705699
# min        0.000000      0.000000
# 25%        4.720000      2.910000
# 50%        5.710000      3.530000
# 75%        6.540000      4.040000
# ...

# %%
# 3
result = dia[['carat', 'price','depth']].agg(["sum", "mean", "max", "min"])
result.to_csv('dia_stat.csv')  # 파일로 저장
result
# Out:
#             carat         price         depth
# sum   43040.87000  2.121352e+08  3.330763e+06
# mean      0.79794  3.932800e+03  6.174940e+01
# max       5.01000  1.882300e+04  7.900000e+01
# min       0.20000  3.260000e+02  4.300000e+01

# %%
# 4
dia.agg({"price":["max", "min"], "color":"nunique"})
# Out:
#            price  color
# max      18823.0    NaN
# min        326.0    NaN
# nunique      NaN    7.0

# %%
# 5
dia["cut"].value_counts().sort_values() # series에서만 가능.
# Out:
# Fair          1610
# Good          4906
# Very Good    12082
# Premium      13791
# Ideal        21551
# Name: cut, dtype: int64

# %%
dia.groupby("cut")["cut"].count().sort_values()
# Out:
# cut
# Fair          1610
# Good          4906
# Very Good    12082
# Premium      13791
# Ideal        21551
# Name: cut, dtype: int64

# %%
# 6
dia.groupby("cut")["price"].mean()
# Out:
# cut
# Fair         4358.757764
# Good         3928.864452
# Ideal        3457.541970
# Premium      4584.257704
# Very Good    3981.759891
# Name: price, dtype: float64

# %%
# 7
re = dia.groupby("cut")["price"].mean()

re[re >= 4000]
# Out:
# cut
# Fair       4358.757764
# Premium    4584.257704
# Name: price, dtype: float64

# %%
# 8

dia["clarity"].value_counts(normalize=True)

dia.groupby("clarity")["carat"].agg(["mean", "std"]).sort_values("mean")

# 평균이 커질 수록 표준편차가 커진다 왜일까. 
# 데이터 셋에 대한 업무, 기술 등 정보 지식을 알아야 한다. => 도메인 지식
# Out:
#              mean       std
# clarity
# VVS1     0.503321  0.299557
# IF       0.505123  0.313433
# VVS2     0.596202  0.359697
# VS1      0.727158  0.423529
# VS2      0.763935  0.446292
# SI1      0.850482  0.449652
# SI2      1.077648  0.516653
# I1       1.283846  0.632436

# %%
# 9 
dia.groupby(["cut","color"]).agg({"price":"mean", "carat":"max"})


# agg 딕셔너리로 조회하면 key 값이 인덱스로 반환되고. 그냥 하면 집계함수가 인덱스 명으로 반환되는데
# Out:
#                        price  carat
# cut       color
# Fair      D      4291.061350   3.40
#           E      3682.312500   2.04
#           F      3827.003205   2.58
#           G      4239.254777   2.60
#           H      5135.683168   4.13
#           I      4685.445714   3.02
#           J      4975.655462   5.01
# Good      D      3405.382175   2.04
#           E      3423.644159   3.00
#           F      3495.750275   2.67
#           G      4123.482204   2.80
#           H      4276.254986   3.01
#           I      5078.532567   3.01
#           J      4574.172638   3.00
# Ideal     D      2629.094566   2.75
#           E      2597.550090   2.28
#           F      3374.939362   2.45
#           G      3720.706388   2.54
#           H      3889.334831   3.50
#           I      4451.970377   3.22
#           J      4918.186384   3.01
# Premium   D      3631.292576   2.57
#           E      3538.914420   3.05
#           F      4324.890176   3.01
# ...

# %%
# 10
re = dia.groupby(["cut","color"]).agg({"price":"mean", "carat":"max"})

re[ (re["price"] >=5000) & (re["carat"].max() >= 3 )]
# Out:
#                        price  carat
# cut       color
# Fair      H      5135.683168   4.13
# Good      I      5078.532567   3.01
# Premium   H      5216.706780   3.24
#           I      5946.180672   4.01
#           J      6294.591584   4.01
# Very Good I      5255.879568   4.00
#           J      5103.513274   2.74
