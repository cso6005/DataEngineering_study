# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
from datetime import datetime

# %%
#python 파일 경로에 data폴더 만든 후 다음의 파일들 넣어놓기
#데이터 불러오기 (pd.read_csv)

f_txt = ['2014','2015', '2016']
df1,df2, df3 = [pd.read_csv(f'data/{txt}년 졸음운전 교통사고.csv',encoding='euc-kr') for txt in f_txt]

# %%
df1.head()
# Out:
#         구분  사고(건)  사망(명)  부상(명)
# 0  2014년1월    169      7    347
# 1  2014년2월    145      3    268
# 2  2014년3월    206     12    358
# 3  2014년4월    182      4    360
# 4  2014년5월    218     17    474

# %%
df2.head()
# Out:
#         구분  사고(건)  사망(명)  부상(명)
# 0  2015년1월    205      8    375
# 1  2015년2월    175      8    375
# 2  2015년3월    237      4    492
# 3  2015년4월    227     10    486
# 4  2015년5월    231      9    504

# %%
df3.head()
# Out:
#         구분  사고(건)  사망(명)  부상(명)
# 0  2016년1월    192      5    387
# 1  2016년2월    174      6    328
# 2  2016년3월    217      7    435
# 3  2016년4월    216      7    419
# 4  2016년5월    239     13    522

# %%
#1. 3개의 데이터를 병합하시오

df = pd.concat([df1,df2,df3])

df
# Out:
#           구분  사고(건)  사망(명)  부상(명)
# 0    2014년1월    169      7    347
# 1    2014년2월    145      3    268
# 2    2014년3월    206     12    358
# 3    2014년4월    182      4    360
# 4    2014년5월    218     17    474
# 5    2014년6월    233     13    457
# 6    2014년7월    229     14    431
# 7    2014년8월    222      9    447
# 8    2014년9월    225     15    430
# 9   2014년10월    210     14    392
# 10  2014년11월    209     10    386
# 11  2014년12월    178     12    329
# 0    2015년1월    205      8    375
# 1    2015년2월    175      8    375
# 2    2015년3월    237      4    492
# 3    2015년4월    227     10    486
# 4    2015년5월    231      9    504
# 5    2015년6월    207      8    401
# 6    2015년7월    273      7    556
# 7    2015년8월    268     19    534
# 8    2015년9월    252     10    501
# 9   2015년10월    214     14    475
# 10  2015년11월    199      3    398
# 11  2015년12월    213      8    428
# 0    2016년1월    192      5    387
# 1    2016년2월    174      6    328
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 36 entries, 0 to 11
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   구분      36 non-null     object
#  1   사고(건)   36 non-null     int64
#  2   사망(명)   36 non-null     int64
#  3   부상(명)   36 non-null     int64
# dtypes: int64(3), object(1)
# memory usage: 1.4+ KB

# %%
#====이후문제는 병합한 데이터프레임을 이용 ===========
#2. 년도, 월별로 인덱스를 설정(멀티인덱스) 하고 데이터를 보여 주시오
df
# Out:
#           구분  사고(건)  사망(명)  부상(명)    년도  월별
# 0    2014년1월    169      7    347  2014   1
# 1    2014년2월    145      3    268  2014   2
# 2    2014년3월    206     12    358  2014   3
# 3    2014년4월    182      4    360  2014   4
# 4    2014년5월    218     17    474  2014   5
# 5    2014년6월    233     13    457  2014   6
# 6    2014년7월    229     14    431  2014   7
# 7    2014년8월    222      9    447  2014   8
# 8    2014년9월    225     15    430  2014   9
# 9   2014년10월    210     14    392  2014  10
# 10  2014년11월    209     10    386  2014  11
# 11  2014년12월    178     12    329  2014  12
# 0    2015년1월    205      8    375  2015   1
# 1    2015년2월    175      8    375  2015   2
# 2    2015년3월    237      4    492  2015   3
# 3    2015년4월    227     10    486  2015   4
# 4    2015년5월    231      9    504  2015   5
# 5    2015년6월    207      8    401  2015   6
# 6    2015년7월    273      7    556  2015   7
# 7    2015년8월    268     19    534  2015   8
# ...

# %%
data1 = pd.to_datetime(df['구분'], format ='%Y년%m월')
data1
# Out:
# 0    2014-01-01
# 1    2014-02-01
# 2    2014-03-01
# 3    2014-04-01
# 4    2014-05-01
# 5    2014-06-01
# 6    2014-07-01
# 7    2014-08-01
# 8    2014-09-01
# 9    2014-10-01
# 10   2014-11-01
# 11   2014-12-01
# 0    2015-01-01
# 1    2015-02-01
# 2    2015-03-01
# 3    2015-04-01
# 4    2015-05-01
# 5    2015-06-01
# 6    2015-07-01
# 7    2015-08-01
# 8    2015-09-01
# 9    2015-10-01
# 10   2015-11-01
# 11   2015-12-01
# 0    2016-01-01
# 1    2016-02-01
# 2    2016-03-01
# 3    2016-04-01
# 4    2016-05-01
# 5    2016-06-01
# 6    2016-07-01
# 7    2016-08-01
# 8    2016-09-01
# 9    2016-10-01
# 10   2016-11-01
# 11   2016-12-01
# Name: 구분, dtype: datetime64[ns]

# %%
df['년도'] = data1.dt.year
df['월별'] = data1.dt.month

df
# Out:
#           구분  사고(건)  사망(명)  부상(명)    년도  월별
# 0    2014년1월    169      7    347  2014   1
# 1    2014년2월    145      3    268  2014   2
# 2    2014년3월    206     12    358  2014   3
# 3    2014년4월    182      4    360  2014   4
# 4    2014년5월    218     17    474  2014   5
# 5    2014년6월    233     13    457  2014   6
# 6    2014년7월    229     14    431  2014   7
# 7    2014년8월    222      9    447  2014   8
# 8    2014년9월    225     15    430  2014   9
# 9   2014년10월    210     14    392  2014  10
# 10  2014년11월    209     10    386  2014  11
# 11  2014년12월    178     12    329  2014  12
# 0    2015년1월    205      8    375  2015   1
# 1    2015년2월    175      8    375  2015   2
# 2    2015년3월    237      4    492  2015   3
# 3    2015년4월    227     10    486  2015   4
# 4    2015년5월    231      9    504  2015   5
# 5    2015년6월    207      8    401  2015   6
# 6    2015년7월    273      7    556  2015   7
# 7    2015년8월    268     19    534  2015   8
# ...

# %%
df.info()
# dt.year 과 dt.month는 int64 타입.!! datatime도 object도 아니다.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 36 entries, 0 to 11
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   구분      36 non-null     object
#  1   사고(건)   36 non-null     int64
#  2   사망(명)   36 non-null     int64
#  3   부상(명)   36 non-null     int64
#  4   년도      36 non-null     int64
#  5   월별      36 non-null     int64
# dtypes: int64(5), object(1)
# memory usage: 3.0+ KB

# %%
df.drop(columns = '구분', inplace = True)
df.set_index(['년도', '월별'], inplace =True)
df
# Out:
#          사고(건)  사망(명)  부상(명)
# 년도   월별
# 2014 1     169      7    347
#      2     145      3    268
#      3     206     12    358
#      4     182      4    360
#      5     218     17    474
#      6     233     13    457
#      7     229     14    431
#      8     222      9    447
#      9     225     15    430
#      10    210     14    392
#      11    209     10    386
#      12    178     12    329
# 2015 1     205      8    375
#      2     175      8    375
#      3     237      4    492
#      4     227     10    486
#      5     231      9    504
#      6     207      8    401
#      7     273      7    556
#      8     268     19    534
#      9     252     10    501
#      10    214     14    475
#      11    199      3    398
#      12    213      8    428
# 2016 1     192      5    387
#      2     174      6    328
#      3     217      7    435
#      4     216      7    419
#      5     239     13    522
#      6     200     12    362
# ...

# %%
df.index
# Out:
# MultiIndex([(2014,  1),
#             (2014,  2),
#             (2014,  3),
#             (2014,  4),
#             (2014,  5),
#             (2014,  6),
#             (2014,  7),
#             (2014,  8),
#             (2014,  9),
#             (2014, 10),
#             (2014, 11),
#             (2014, 12),
#             (2015,  1),
#             (2015,  2),
#             (2015,  3),
#             (2015,  4),
#             (2015,  5),
#             (2015,  6),
#             (2015,  7),
#             (2015,  8),
#             (2015,  9),
#             (2015, 10),
#             (2015, 11),
#             (2015, 12),
#             (2016,  1),
#             (2016,  2),
#             (2016,  3),
#             (2016,  4),
#             (2016,  5),
#             (2016,  6),
#             (2016,  7),
#             (2016,  8),
#             (2016,  9),
#             (2016, 10),
#             (2016, 11),
#             (2016, 12)],
#            names=['년도', '월별'])

# %%
#df['년도'] = df['구분'].str.slice(0,4)
#df['월별'] = df['구분'].str.slice(5)

#df.drop(columns = '구분', inplace = True)
#df.set_index(['년도','월별'], inplace = True)
#df

# %%
#3. 년도 및 월별 평균 사망자를 보여주시오

df.pivot_table(index = '월별', columns = '년도', values = '사망(명)')
# Out:
# 년도  2014  2015  2016
# 월별
# 1      7     8     5
# 2      3     8     6
# 3     12     4     7
# 4      4    10     7
# 5     17     9    13
# 6     13     8    12
# 7     14     7     9
# 8      9    19     7
# 9     15    10    13
# 10    14    14    10
# 11    10     3     5
# 12    12     8     4

# %%
df
# Out:
#          사고(건)  사망(명)  부상(명)
# 년도   월별
# 2014 1     169      7    347
#      2     145      3    268
#      3     206     12    358
#      4     182      4    360
#      5     218     17    474
#      6     233     13    457
#      7     229     14    431
#      8     222      9    447
#      9     225     15    430
#      10    210     14    392
#      11    209     10    386
#      12    178     12    329
# 2015 1     205      8    375
#      2     175      8    375
#      3     237      4    492
#      4     227     10    486
#      5     231      9    504
#      6     207      8    401
#      7     273      7    556
#      8     268     19    534
#      9     252     10    501
#      10    214     14    475
#      11    199      3    398
#      12    213      8    428
# 2016 1     192      5    387
#      2     174      6    328
#      3     217      7    435
#      4     216      7    419
#      5     239     13    522
#      6     200     12    362
# ...

# %%
df.loc[('2016')]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\envs\ml\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\envs\ml\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# pandas\_libs\index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: '2016'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13848\2434372828.py in <module>
# ----> 1 df.loc[('2016')]
#
# ...

# %%
#4.  2016년 사고대비 사망율을 구하시오

round(df.groupby('년도')['사망(명)'].sum()[2016]/df.groupby('년도')['사고(건)'].sum()[2016], 4)
# Out:
# 0.0403

# %%
#4.  2016년 사고대비 사망율을 구하시오
# 월별
df16 = round((df.loc[2016]['사망(명)'])/(df.loc[2016]['사고(건)']),4)
df16
# Out:
# 월별
# 1     0.0260
# 2     0.0345
# 3     0.0323
# 4     0.0324
# 5     0.0544
# 6     0.0600
# 7     0.0396
# 8     0.0304
# 9     0.0695
# 10    0.0546
# 11    0.0250
# 12    0.0238
# dtype: float64

# %%
#4.  2016년 월별 사고대비 사망율 시각화

df16.plot(kind ='line')
plt.title('2016년 사고대비 사망율')
plt.show()

# %%
#4.  2016년 사고대비 사망율을 구하시오
# 전체
round((df.loc[2016]['사망(명)'].sum())/(df.loc[2016]['사고(건)'].sum()),4)
# Out:
# 0.0403

# %%
#5. 2014년도 월별 사망, 부상 데이터를 바차트로 보여주시오

fig = plt.figure(figsize = (15, 5))
ax1 = fig.add_subplot(1,2,1)
ax2 = fig.add_subplot(1,2,2)


df.loc[2014,['사망(명)', '부상(명)']].plot(kind = 'bar',figsize=(9,5), rot = 30,title = '2014년도 월별 사망, 부상 막대그래프', ax =ax1)

plt.title('2014년도 월별 사망, 부상 선그래프') # 이렇게 하면 ax2에만 title 생김. # ax1에 넣으려면 plot 매개변수로 넣어야 함.
df.loc[2014,['사망(명)', '부상(명)']].plot(kind = 'line',figsize=(9,5), rot = 30, ax =ax2)


plt.show()

# %%
#6. 2015년 대비  사망이 가장 많이 증가한 2016년도 월을 구하시오

# %%
# 변수 넣어 구하기
x = df.loc[2016,'사망(명)'] - df.loc[2015,'사망(명)']
x[x == x.max()]
# Out:
# 월별
# 5    4
# 6    4
# Name: 사망(명), dtype: int64

# %%
# 중복된 큰 값 인덱스 구하려면 ? 
# nlargest : 상위   nsmallest : 하위
# 1 : 상위 1
# keep = all : 중복 허용


(ans2.loc[2016,'사망(명)'] - ans2.loc[2015,'사망(명)']).nlargest(1,keep='all')

# %%
# .idxmax() 의 경우 가장큰값이 중복일 경우 가장 앞 인덱스만을 반환한다.

(df.loc[2016,'사망(명)'] - df.loc[2015,'사망(명)']).idxmax()
# Out:
# 5

# %%
# filter, enumerate로 구해보기
# x.filter(items = (lambda i,j : enumerate(x.values)))
